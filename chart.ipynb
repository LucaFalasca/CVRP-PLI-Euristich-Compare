# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# importo il file in numnpy
data = pd.read_csv("mip-results.csv")
data_np = data.to_numpy()

# faccio il grafico di N vs gap
N = data["N"]
gap = data["Optimality_Gap(%)"]
plt.plot(N, gap, marker='o')
plt.xlabel('N')
plt.ylabel('Optimality Gap (%)')
plt.title('Grafico di N vs Gap')
plt.grid()
plt.show()

# %%
# Grafico di qualità della soluzione negli algoritmi euristici

data_clarke = pd.read_csv("clarke-results.csv")
data_sweep = pd.read_csv("sweep-results.csv")
data_my_euristich = pd.read_csv("my-euristich-results.csv")
data_mip = pd.read_csv("mip-results.csv")

# tolto i nan
#data_clarke = data_clarke.dropna()
#data_sweep = data_sweep.dropna()
#data_my_euristich = data_my_euristich.dropna()

N = data_clarke["N"]
K = data_clarke["K"]
gap_clarke = data_clarke["Optimality_Gap(%)"]
gap_sweep = data_sweep["Optimality_Gap(%)"]
gap_my_euristich = data_my_euristich["Optimality_Gap(%)"]
gap_mip = data["Optimality_Gap(%)"]
plt.plot(N, gap_clarke, marker='o', linestyle='-', label='Clarke-Wright')
plt.plot(N, gap_sweep, marker='o', linestyle='-', label='Sweep')
plt.plot(N, gap_my_euristich, marker='o', linestyle='-', label='My Euristich')
plt.plot(N, gap_mip, marker='o', linestyle='-', label='MIP', color='black')
plt.xlabel('N')
plt.ylabel('Optimality Gap (%)')
plt.title('Grafico di N vs Gap per Algoritmi Euristici')
plt.legend()
plt.grid()
plt.show()

#Grafico con K usando le medie dei gap per ogni K
gap_clarke_K = data_clarke.groupby("K")["Optimality_Gap(%)"].mean()
gap_sweep_K = data_sweep.groupby("K")["Optimality_Gap(%)"].mean()
gap_my_euristich_K = data_my_euristich.groupby("K")["Optimality_Gap(%)"].mean()
gap_mip_K = data_mip.groupby("K")["Optimality_Gap(%)"].mean()
K = gap_clarke_K.index
plt.figure(figsize=(10, 6))
plt.plot(K, gap_clarke_K, label='Clarke-Wright', alpha=0.7)
plt.plot(K, gap_sweep_K, label='Sweep', alpha=0.7)
plt.plot(K, gap_my_euristich_K, label='My Euristich', alpha=0.7)
plt.plot(K, gap_mip_K, label='MIP', alpha=0.7, color='black')
plt.xlabel('K')
plt.ylabel('AVG Optimality Gap (%)')
plt.title('Grafico di K vs Gap per Algoritmi Euristici')
plt.legend()
plt.grid()
plt.show()

# Faccio il grafico a candela con gli stessi dati
gap_clarke = gap_clarke.dropna()
plt.figure(figsize=(10, 6))
plt.boxplot([gap_clarke, gap_sweep, gap_my_euristich, gap_mip], labels=['Clarke-Wright', 'Sweep', 'My Euristich', 'MIP'])
plt.ylabel('Optimality Gap (%)')
plt.title('Boxplot dei Gap per Algoritmi Euristici')
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_962959/791505112.py:51: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([gap_clarke, gap_sweep, gap_my_euristich, gap_mip], labels=['Clarke-Wright', 'Sweep', 'My Euristich', 'MIP'])

# %%
# Grafico di tempo di esecuzione negli algoritmi euristici

plt.figure(figsize=(10, 6))
time_clarke = data_clarke["Processing_Time(s)"]
time_sweep = data_sweep["Processing_Time(s)"]
time_my_euristich = data_my_euristich["Processing_Time(s)"]
time_mip = data["Processing_Time(s)"]
plt.plot(N, time_clarke, marker='o', linestyle='-', label='Clarke-Wright')
plt.plot(N, time_sweep, marker='o', linestyle='-', label='Sweep')
plt.plot(N, time_my_euristich, marker='o', linestyle='-', label='My Euristich')
#plt.plot(N, time_mip, marker='o', linestyle='-', label='MIP', color='black')
plt.xlabel('N')
plt.ylabel('Time (s)')
plt.title('Grafico di N vs Time per Algoritmi Euristici')
plt.legend()
plt.grid()
plt.yscale('log')  # scala logaritmica per il tempo
plt.show()

# %%
# Grafico di gap/time al variare di N

plt.figure(figsize=(10, 6))
plt.plot(N, gap_clarke / time_clarke, marker='o', linestyle='-', label='Clarke-Wright')
plt.plot(N, gap_sweep / time_sweep, marker='o', linestyle='-', label='Sweep')
plt.plot(N, gap_my_euristich / time_my_euristich, marker='o', linestyle='-', label='My Euristich')
plt.plot(N, gap_mip / time_mip, marker='o', linestyle='-', label='MIP', color='black')
plt.xlabel('N')
plt.ylabel('Gap/Time (%/s)')
plt.title('Grafico di N vs Gap/Time per Algoritmi Euristici')
plt.legend()
plt.grid()
plt.show()

# %%
# Grafici su XML100
data_xml_100_aggs = []
for file in ["clarke-results-XML100.csv", "sweep-results-XML100.csv", "my-euristich-results-XML100.csv"]:
    
    data_xml100 = pd.read_csv(file)

    # trasformo ogni numero in una stringa specifica (1: random, 2: centered, 3: cornered)
    data_xml100_depot = data_xml100["Instance"].str[7:8]
    # Customers (1: random, 2: clustered, 3: random-clustered)
    data_xml100_customers = data_xml100["Instance"].str[8:9]
    # Demand (1. unitary, 2. small values with large CV, 3. small values with small CV, 4. large values with large CV, 5. large values with small CV, 6. depending on quadrant, 7. many small values and few large values)
    data_xml100_demand = data_xml100["Instance"].str[9:10]
    # Route size (1: very short, 2: short, 3: medium, 4: long, 5: very long, 6: ultra long)
    data_xml100_route_size = data_xml100["Instance"].str[10:11]
    # aggiungo tutto al dataframe
    data_xml100["Depot"] = data_xml100_depot
    data_xml100["Customers"] = data_xml100_customers
    data_xml100["Demand"] = data_xml100_demand
    data_xml100["Route_Size"] = data_xml100_route_size

    # aggrego i dati per ogni enumerazione di caratteristiche e calcolo la media del gap e del tempo
    data_xml100_agg1 = data_xml100.groupby(["Depot"]).agg({"Optimality_Gap(%)": "mean", "Processing_Time(s)": "mean"}).reset_index().replace({'1': 'Depot random', '2': 'Depot centered', '3': 'Depot cornered'}).rename(columns={"Depot": "Characteristic"})

    print(data_xml100_agg1)

    data_xml100_agg2 = data_xml100.groupby(["Customers"]).agg({"Optimality_Gap(%)": "mean", "Processing_Time(s)": "mean"}).reset_index().replace({'1': 'Customers random', '2': 'Customers clustered', '3': 'Customers random-clustered'}).rename(columns={"Customers": "Characteristic"})
    print(data_xml100_agg2)

    data_xml100_agg3 = data_xml100.groupby(["Demand"]).agg({"Optimality_Gap(%)": "mean", "Processing_Time(s)": "mean"}).reset_index().replace({'1': 'Demand unitary', '2': 'Demand small values with large CV', '3': 'Demand small values with small CV', '4': 'Demand large values with large CV', '5': 'Demand large values with small CV', '6': 'Demand depending on quadrant', '7': 'Demand many small values and few large values'}).rename(columns={"Demand": "Characteristic"})
    print(data_xml100_agg3)

    data_xml100_agg4 = data_xml100.groupby(["Route_Size"]).agg({"Optimality_Gap(%)": "mean", "Processing_Time(s)": "mean"}).reset_index().replace({'1': 'Route_Size very short', '2': 'Route_Size short', '3': 'Route_Size medium', '4': 'Route_Size long', '5': 'Route_Size very long', '6': 'Route_Size ultra long'}).rename(columns={"Route_Size": "Characteristic"})
    print(data_xml100_agg4)

    # Unisco tutte e 4 sotto un unico dataframe unendo la prima colonna come una sola
    data_xml100_agg = pd.merge(data_xml100_agg1, data_xml100_agg2, how='outer')
    data_xml100_agg = pd.merge(data_xml100_agg, data_xml100_agg3, how='outer')
    data_xml100_agg = pd.merge(data_xml100_agg, data_xml100_agg4, how='outer')
    data_xml_100_aggs.append(data_xml100_agg)
    print(data_xml100_agg)

# Faccio un grafico a barre con i dati aggregati
labels = data_xml_100_aggs[0]["Characteristic"]
gap_values_clarke = data_xml_100_aggs[0]["Optimality_Gap(%)"]
gap_values_sweep = data_xml_100_aggs[1]["Optimality_Gap(%)"]
gap_values_my_euristich = data_xml_100_aggs[2]["Optimality_Gap(%)"]
time_values_clarke = data_xml_100_aggs[0]["Processing_Time(s)"]
time_values_sweep = data_xml_100_aggs[1]["Processing_Time(s)"]
time_values_my_euristich = data_xml_100_aggs[2]["Processing_Time(s)"]
x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots(figsize=(16, 9))
bars1 = ax.bar(x - width, gap_values_clarke, width, label='Optimality Gap clarke (%)')
bars2 = ax.bar(x, gap_values_sweep, width, label='Optimality Gap sweep (%)')
bars3 = ax.bar(x + width, gap_values_my_euristich, width, label='Optimality Gap my euristich (%)')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
ax.set_title('Optimality Gap - XML100')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha="right")
ax.legend()

fig, ax = plt.subplots(figsize=(16, 9))
bars2 = ax.bar(x - width, time_values_clarke, width, label='Processing Time clarke (s)')
bars3 = ax.bar(x, time_values_sweep, width, label='Processing Time sweep (s)')
bars4 = ax.bar(x + width, time_values_my_euristich, width, label='Processing Time my euristich (s)')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
ax.set_yscale('log')  # scala logaritmica per il tempo
ax.set_title('Processing Time - XML100')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha="right")
ax.legend()

# metto su file

data_sweep_xml100 = pd.read_csv("sweep-results-XML100.csv")
data_my_euristich_xml100 = pd.read_csv("my-euristich-results-XML100.csv")

# faccio un
# Out:
#    Characteristic  Optimality_Gap(%)  Processing_Time(s)
# 0    Depot random          31.899850            0.040499
# 1  Depot centered          34.573200            0.036422
# 2  Depot cornered          27.480366            0.041488
#                Characteristic  Optimality_Gap(%)  Processing_Time(s)
# 0            Customers random          34.539315            0.039662
# 1         Customers clustered          27.016126            0.039865
# 2  Customers random-clustered          32.429617            0.038876
#                                   Characteristic  Optimality_Gap(%)  \
# 0                                 Demand unitary          30.166774
# 1              Demand small values with large CV          31.256436
# 2              Demand small values with small CV          31.888424
# 3              Demand large values with large CV          30.971275
# 4              Demand large values with small CV          32.032367
# 5                   Demand depending on quadrant          31.816730
# 6  Demand many small values and few large values          31.252080
#
#    Processing_Time(s)
# 0            0.039545
# 1            0.039503
# 2            0.039138
# 3            0.039506
# 4            0.039827
# 5            0.039426
# 6            0.039334
#           Characteristic  Optimality_Gap(%)  Processing_Time(s)
# 0  Route_Size very short           8.200642            0.049297
# 1       Route_Size short          15.123263            0.042563
# 2      Route_Size medium          24.901452            0.038650
# 3        Route_Size long          34.224943            0.036890
# 4   Route_Size very long          45.478115            0.035682
# 5  Route_Size ultra long          60.138025            0.033724
#                                    Characteristic  Optimality_Gap(%)  \
# 0                             Customers clustered          27.016126
# 1                                Customers random          34.539315
# 2                      Customers random-clustered          32.429617
# 3                    Demand depending on quadrant          31.816730
# 4               Demand large values with large CV          30.971275
# 5               Demand large values with small CV          32.032367
# 6   Demand many small values and few large values          31.252080
# 7               Demand small values with large CV          31.256436
# 8               Demand small values with small CV          31.888424
# 9                                  Demand unitary          30.166774
# 10                                 Depot centered          34.573200
# 11                                 Depot cornered          27.480366
# 12                                   Depot random          31.899850
# 13                                Route_Size long          34.224943
# 14                              Route_Size medium          24.901452
# 15                               Route_Size short          15.123263
# 16                          Route_Size ultra long          60.138025
# 17                           Route_Size very long          45.478115
# 18                          Route_Size very short           8.200642
#
#     Processing_Time(s)
# 0             0.039865
# 1             0.039662
# 2             0.038876
# 3             0.039426
# 4             0.039506
# 5             0.039827
# 6             0.039334
# 7             0.039503
# 8             0.039138
# 9             0.039545
# 10            0.036422
# 11            0.041488
# 12            0.040499
# 13            0.036890
# 14            0.038650
# 15            0.042563
# 16            0.033724
# 17            0.035682
# 18            0.049297
#    Characteristic  Optimality_Gap(%)  Processing_Time(s)
# 0    Depot random          96.777269            0.000173
# 1  Depot centered          75.371734            0.000183
# 2  Depot cornered         121.628993            0.000178
#                Characteristic  Optimality_Gap(%)  Processing_Time(s)
# 0            Customers random         109.357170            0.000182
# 1         Customers clustered          84.269088            0.000175
# 2  Customers random-clustered          99.667194            0.000177
#                                   Characteristic  Optimality_Gap(%)  \
# 0                                 Demand unitary          92.369092
# 1              Demand small values with large CV          98.433424
# 2              Demand small values with small CV          97.814202
# 3              Demand large values with large CV          96.180217
# 4              Demand large values with small CV          97.521331
# 5                   Demand depending on quadrant          98.902647
# 6  Demand many small values and few large values         103.448746
#
#    Processing_Time(s)
# 0            0.000175
# 1            0.000176
# 2            0.000176
# 3            0.000180
# 4            0.000181
# 5            0.000176
# 6            0.000181
#           Characteristic  Optimality_Gap(%)  Processing_Time(s)
# 0  Route_Size very short          39.332496            0.000210
# 1       Route_Size short          59.386395            0.000185
# 2      Route_Size medium          84.784841            0.000173
# 3        Route_Size long         107.614391            0.000171
# 4   Route_Size very long         132.155612            0.000164
# 5  Route_Size ultra long         163.633007            0.000164
#                                    Characteristic  Optimality_Gap(%)  \
# 0                             Customers clustered          84.269088
# 1                                Customers random         109.357170
# 2                      Customers random-clustered          99.667194
# 3                    Demand depending on quadrant          98.902647
# 4               Demand large values with large CV          96.180217
# 5               Demand large values with small CV          97.521331
# 6   Demand many small values and few large values         103.448746
# 7               Demand small values with large CV          98.433424
# 8               Demand small values with small CV          97.814202
# 9                                  Demand unitary          92.369092
# 10                                 Depot centered          75.371734
# 11                                 Depot cornered         121.628993
# 12                                   Depot random          96.777269
# 13                                Route_Size long         107.614391
# 14                              Route_Size medium          84.784841
# 15                               Route_Size short          59.386395
# 16                          Route_Size ultra long         163.633007
# 17                           Route_Size very long         132.155612
# 18                          Route_Size very short          39.332496
#
#     Processing_Time(s)
# 0             0.000175
# 1             0.000182
# 2             0.000177
# 3             0.000176
# 4             0.000180
# 5             0.000181
# 6             0.000181
# 7             0.000176
# 8             0.000176
# 9             0.000175
# 10            0.000183
# 11            0.000178
# 12            0.000173
# 13            0.000171
# 14            0.000173
# 15            0.000185
# 16            0.000164
# 17            0.000164
# 18            0.000210
#    Characteristic  Optimality_Gap(%)  Processing_Time(s)
# 0    Depot random              100.0            0.000010
# 1  Depot centered              100.0            0.000009
# 2  Depot cornered              100.0            0.000009
#                Characteristic  Optimality_Gap(%)  Processing_Time(s)
# 0            Customers random              100.0            0.000009
# 1         Customers clustered              100.0            0.000009
# 2  Customers random-clustered              100.0            0.000010
#                                   Characteristic  Optimality_Gap(%)  \
# 0                                 Demand unitary              100.0
# 1              Demand small values with large CV              100.0
# 2              Demand small values with small CV              100.0
# 3              Demand large values with large CV              100.0
# 4              Demand large values with small CV              100.0
# 5                   Demand depending on quadrant              100.0
# 6  Demand many small values and few large values              100.0
#
#    Processing_Time(s)
# 0            0.000009
# 1            0.000009
# 2            0.000010
# 3            0.000010
# 4            0.000009
# 5            0.000009
# 6            0.000009
#           Characteristic  Optimality_Gap(%)  Processing_Time(s)
# 0  Route_Size very short              100.0            0.000010
# 1       Route_Size short              100.0            0.000009
# 2      Route_Size medium              100.0            0.000010
# 3        Route_Size long              100.0            0.000009
# 4   Route_Size very long              100.0            0.000009
# 5  Route_Size ultra long              100.0            0.000009
#                                    Characteristic  Optimality_Gap(%)  \
# 0                             Customers clustered              100.0
# 1                                Customers random              100.0
# 2                      Customers random-clustered              100.0
# 3                    Demand depending on quadrant              100.0
# 4               Demand large values with large CV              100.0
# 5               Demand large values with small CV              100.0
# 6   Demand many small values and few large values              100.0
# 7               Demand small values with large CV              100.0
# 8               Demand small values with small CV              100.0
# 9                                  Demand unitary              100.0
# 10                                 Depot centered              100.0
# 11                                 Depot cornered              100.0
# 12                                   Depot random              100.0
# 13                                Route_Size long              100.0
# 14                              Route_Size medium              100.0
# 15                               Route_Size short              100.0
# 16                          Route_Size ultra long              100.0
# 17                           Route_Size very long              100.0
# 18                          Route_Size very short              100.0
#
#     Processing_Time(s)
# 0             0.000009
# 1             0.000009
# 2             0.000010
# 3             0.000009
# 4             0.000010
# 5             0.000009
# 6             0.000009
# 7             0.000009
# 8             0.000010
# 9             0.000009
# 10            0.000009
# 11            0.000009
# 12            0.000010
# 13            0.000009
# 14            0.000010
# 15            0.000009
# 16            0.000009
# 17            0.000009
# 18            0.000010
